# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\python311\lib\site-packages (3.8.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python311\lib\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\madhavi bansal\appdata\roaming\python\python311\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\python311\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\madhavi bansal\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\madhavi bansal\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import time
import random
import threading
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import pygame
import matplotlib.pyplot as plt

# Initialize Pygame mixer for playing sounds
pygame.mixer.init()

# Function to get real sensor data (replace with actual implementation)
def get_real_sensor_data():
    # In a real-world scenario, this function would obtain actual sensor readings
    temperature = 98.6 + random.uniform(-0.5, 0.5)
    blood_pressure = 120 + random.uniform(-5, 5)
    return temperature, blood_pressure

# Function for real-time data collection and plotting
def collect_data(model):
    # Lists to store historical sensor readings
    temperature_history = []
    blood_pressure_history = []

    # Create figure and axes for subplots
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

    while True:
        temperature, blood_pressure = get_real_sensor_data()

        # Use the trained model for prediction
        status = model.predict(np.array([[temperature, blood_pressure]]))[0]

        print(f'Temperature: {temperature:.2f}°F, Blood Pressure: {blood_pressure:.2f} mmHg, Status: {"Normal" if status == 1 else "Abnormal"}')

        # Append readings to history lists
        temperature_history.append(temperature)
        blood_pressure_history.append(blood_pressure)

        # Update real-time plots
        axes[0].clear()
        axes[1].clear()

        axes[0].plot(temperature_history, label='Temperature', color='blue')
        axes[0].set_title('Temperature History')
        axes[0].set_xlabel('Time')
        axes[0].set_ylabel('Temperature (°F)')

        axes[1].plot(blood_pressure_history, label='Blood Pressure', color='red')
        axes[1].set_title('Blood Pressure History')
        axes[1].set_xlabel('Time')
        axes[1].set_ylabel('Blood Pressure (mmHg)')

        plt.tight_layout()
        plt.pause(0.1)  # Pause to allow the plot to update

        if status == 0:
            # If the status is abnormal, play an alarm sound
            pygame.mixer.music.load("Alarm.mp3")  # Replace with the path to your alarm sound file
            pygame.mixer.music.play()

        time.sleep(1)  # Simulate a delay to mimic real-time data collection

# Sample data for training the model
training_data = {
    'Temperature': [98.6, 99.2, 97.8, 98.5, 99.0, 97.5],
    'BloodPressure': [120, 122, 118, 119, 121, 117],
    'Normal': [1, 1, 0, 1, 1, 0]  # 1 for normal, 0 for abnormal
}

df = pd.DataFrame(training_data)

# Split the data into features and target
X_train = df[['Temperature', 'BloodPressure']]
y_train = df['Normal']

# Create and train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Create a separate thread for real-time data collection
real_time_thread = threading.Thread(target=collect_data, args=(model,))
real_time_thread.start()

# Main thread can perform other tasks or wait for real-time data collection to finish
real_time_thread.join()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.54°F, Blood Pressure: 124.07 mmHg, Status: Normal
# Temperature: 98.40°F, Blood Pressure: 119.57 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.58°F, Blood Pressure: 122.74 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.62°F, Blood Pressure: 120.38 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.33°F, Blood Pressure: 122.97 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.31°F, Blood Pressure: 121.71 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.97°F, Blood Pressure: 119.04 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.64°F, Blood Pressure: 115.53 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.58°F, Blood Pressure: 120.32 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.22°F, Blood Pressure: 119.80 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.91°F, Blood Pressure: 116.25 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.83°F, Blood Pressure: 117.80 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 99.00°F, Blood Pressure: 119.11 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 99.06°F, Blood Pressure: 117.52 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.62°F, Blood Pressure: 121.96 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.99°F, Blood Pressure: 117.59 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.58°F, Blood Pressure: 117.90 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.94°F, Blood Pressure: 116.42 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.32°F, Blood Pressure: 124.31 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.26°F, Blood Pressure: 117.77 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.53°F, Blood Pressure: 123.06 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.48°F, Blood Pressure: 124.87 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.48°F, Blood Pressure: 124.35 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.74°F, Blood Pressure: 123.97 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 99.09°F, Blood Pressure: 120.59 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.83°F, Blood Pressure: 120.09 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.30°F, Blood Pressure: 118.52 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.17°F, Blood Pressure: 121.19 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.89°F, Blood Pressure: 121.39 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.45°F, Blood Pressure: 120.76 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.43°F, Blood Pressure: 120.60 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.16°F, Blood Pressure: 118.49 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.30°F, Blood Pressure: 120.89 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 99.09°F, Blood Pressure: 123.83 mmHg, Status: Normal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Temperature: 98.86°F, Blood Pressure: 116.62 mmHg, Status: Abnormal
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
